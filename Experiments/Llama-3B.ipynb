# %%
# !pip install unsloth vllm
# !pip install --upgrade pillow
# !pip install git+https://github.com/huggingface/trl.git@e95f9fb74a3c3647b86f251b7e230ec51c64b72b
# Out:
# Requirement already satisfied: unsloth in /usr/local/lib/python3.11/dist-packages (2025.3.19)
# Requirement already satisfied: vllm in /usr/local/lib/python3.11/dist-packages (0.8.2)
# Requirement already satisfied: unsloth_zoo>=2025.3.17 in /usr/local/lib/python3.11/dist-packages (from unsloth) (2025.3.17)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (2.6.0+cu124)
# Requirement already satisfied: xformers>=0.0.27.post2 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.0.29.post2)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.45.4)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (3.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from unsloth) (24.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.9.18)
# Requirement already satisfied: transformers!=4.47.0,>=4.46.1 in /usr/local/lib/python3.11/dist-packages (from unsloth) (4.50.0)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (3.5.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unsloth) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from unsloth) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.11/dist-packages (from unsloth) (1.5.2)
# Requirement already satisfied: trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.15.0.dev0)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.14.0)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (3.20.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.29.3)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.32.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.21.0+cu124)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from vllm) (5.5.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.32.3)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.0.4)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from vllm) (9.0.0)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.21.1)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.115.12)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from vllm) (3.11.14)
# Requirement already satisfied: openai>=1.52.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.68.2)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.10.6)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.21.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from vllm) (11.1.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.9.0)
# Requirement already satisfied: lm-format-enforcer<0.11,>=0.10.11 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.10.11)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.9 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.7.11)
# Requirement already satisfied: outlines==0.1.11 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.1.11)
# Requirement already satisfied: lark==1.2.2 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.2.2)
# Requirement already satisfied: xgrammar==0.1.16 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.1.16)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.11/dist-packages (from vllm) (4.13.0)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (3.18.0)
# Requirement already satisfied: partial-json-parser in /usr/local/lib/python3.11/dist-packages (from vllm) (0.2.1.1.post5)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.11/dist-packages (from vllm) (24.0.1)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.11/dist-packages (from vllm) (0.19.0)
# Requirement already satisfied: gguf==0.10.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.10.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from vllm) (8.6.1)
# Requirement already satisfied: mistral_common>=1.5.4 in /usr/local/lib/python3.11/dist-packages (from mistral_common[opencv]>=1.5.4->vllm) (1.5.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from vllm) (6.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from vllm) (0.8.1)
# Requirement already satisfied: compressed-tensors==0.9.2 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.9.2)
# Requirement already satisfied: depyf==0.18.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.18.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from vllm) (3.1.1)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.11/dist-packages (from vllm) (1.0.4)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.11/dist-packages (from vllm) (3.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from vllm) (1.14.1)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from vllm) (1.11.1.4)
# Requirement already satisfied: numba==0.60.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.60.0)
# Requirement already satisfied: ray>=2.43.0 in /usr/local/lib/python3.11/dist-packages (from ray[cgraph]>=2.43.0->vllm) (2.44.1)
# Requirement already satisfied: torchaudio==2.6.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.6.0+cu124)
# Requirement already satisfied: astor in /usr/local/lib/python3.11/dist-packages (from depyf==0.18.0->vllm) (0.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from depyf==0.18.0->vllm) (0.3.8)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba==0.60.0->vllm) (0.43.0)
# Requirement already satisfied: interegular in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (0.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (3.1.6)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (1.6.0)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (5.6.3)
# Requirement already satisfied: referencing in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (4.23.0)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (24.6.1)
# Requirement already satisfied: airportsdata in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (20250224)
# Requirement already satisfied: outlines_core==0.1.26 in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (0.1.26)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.1->unsloth) (0.5.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (18.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (0.70.16)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.46.1)
# Requirement already satisfied: fastapi-cli>=0.0.5 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.0.7)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.28.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]>=0.115.0->vllm) (2.2.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.34.0)
# Requirement already satisfied: opencv-python-headless>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mistral_common[opencv]>=1.5.4->vllm) (4.11.0.86)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm) (2.27.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.43.0->ray[cgraph]>=2.43.0->vllm) (8.1.8)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.43.0->ray[cgraph]>=2.43.0->vllm) (1.1.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray>=2.43.0->ray[cgraph]>=2.43.0->vllm) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray>=2.43.0->ray[cgraph]>=2.43.0->vllm) (1.5.0)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.11/dist-packages (from ray[cgraph]>=2.43.0->vllm) (13.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (2025.1.31)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.6.0->vllm) (2024.11.6)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth) (13.9.4)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.3.17->unsloth) (25.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (25.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (1.18.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->vllm) (3.21.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth) (0.16)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth) (1.7.1)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth) (4.4.2)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm) (2.7.0)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.15.2)
# Requirement already satisfied: rich-toolkit>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.14.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->fastapi[standard]>=0.115.0->vllm) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->fastapi[standard]>=0.115.0->vllm) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->outlines==0.1.11->vllm) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm) (0.23.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth) (2.18.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (1.1.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (15.0.1)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.11/dist-packages (from cupy-cuda12x->ray[cgraph]>=2.43.0->vllm) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2025.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (1.5.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Collecting git+https://github.com/huggingface/trl.git@e95f9fb74a3c3647b86f251b7e230ec51c64b72b
#   Cloning https://github.com/huggingface/trl.git (to revision e95f9fb74a3c3647b86f251b7e230ec51c64b72b) to /tmp/pip-req-build-x0u282sh
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/trl.git /tmp/pip-req-build-x0u282sh
#   Running command git rev-parse -q --verify 'sha^e95f9fb74a3c3647b86f251b7e230ec51c64b72b'
#   Running command git fetch -q https://github.com/huggingface/trl.git e95f9fb74a3c3647b86f251b7e230ec51c64b72b
#   Running command git checkout -q e95f9fb74a3c3647b86f251b7e230ec51c64b72b
#   Resolved https://github.com/huggingface/trl.git to commit e95f9fb74a3c3647b86f251b7e230ec51c64b72b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from trl==0.15.0.dev0) (1.5.2)
# Requirement already satisfied: datasets>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from trl==0.15.0.dev0) (3.5.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl==0.15.0.dev0) (13.9.4)
# Requirement already satisfied: transformers>=4.46.0 in /usr/local/lib/python3.11/dist-packages (from trl==0.15.0.dev0) (4.50.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl==0.15.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl==0.15.0.dev0) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl==0.15.0.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl==0.15.0.dev0) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl==0.15.0.dev0) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl==0.15.0.dev0) (0.29.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl==0.15.0.dev0) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.0.dev0) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.0.dev0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.0.dev0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.0.dev0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.0.dev0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.0.dev0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.0.dev0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.0.dev0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.21.0->trl==0.15.0.dev0) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.0.dev0) (3.11.14)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.0->trl==0.15.0.dev0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.0->trl==0.15.0.dev0) (0.21.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl==0.15.0.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl==0.15.0.dev0) (2.18.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.0.dev0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.0.dev0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.0.dev0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.0.dev0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.0.dev0) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.0.dev0) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.0.dev0) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate>=0.34.0->trl==0.15.0.dev0) (4.13.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl==0.15.0.dev0) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl==0.15.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl==0.15.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl==0.15.0.dev0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl==0.15.0.dev0) (2025.1.31)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.21.0->trl==0.15.0.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.21.0->trl==0.15.0.dev0) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.21.0->trl==0.15.0.dev0) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.21.0->trl==0.15.0.dev0) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate>=0.34.0->trl==0.15.0.dev0) (3.0.2)

# %%
from unsloth import FastLanguageModel, PatchFastRL
PatchFastRL("GRPO", FastLanguageModel)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-31 13:33:32 [__init__.py:239] Automatically detected platform cuda.

# %%
from unsloth import is_bfloat16_supported
import torch
max_seq_length = 512
lora_rank = 8

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "meta-llama/meta-Llama-3.1-8B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True,
    fast_inference = True,
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.6,
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",],
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth",
)
# Out:
# ==((====))==  Unsloth 2025.3.19: Fast Llama patching. Transformers: 4.50.0. vLLM: 0.8.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit with actual GPU utilization = 59.43%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 512. Num Sequences = 160.
# Unsloth: vLLM's KV Cache can use up to 2.7 GB. Also swap space = 2 GB.
# WARNING 03-31 13:33:44 [config.py:2614] Casting torch.bfloat16 to torch.float16.
# INFO 03-31 13:34:10 [config.py:585] This model supports multiple tasks: {'reward', 'score', 'generate', 'embed', 'classify'}. Defaulting to 'generate'.
# WARNING 03-31 13:34:11 [arg_utils.py:1854] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'float16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 03-31 13:34:11 [llm_engine.py:241] Initializing a V0 LLM engine (v0.8.2) with config: model='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=512, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":160}, use_cached_outputs=False,
# tokenizer_config.json:   0%|          | 0.00/55.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# INFO 03-31 13:34:16 [cuda.py:239] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 03-31 13:34:16 [cuda.py:288] Using XFormers backend.
# INFO 03-31 13:34:18 [parallel_state.py:954] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# INFO 03-31 13:34:18 [model_runner.py:1110] Starting to load model unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit...
# INFO 03-31 13:34:18 [loader.py:1155] Loading weights with BitsAndBytes quantization. May take a while ...
# INFO 03-31 13:34:19 [weight_utils.py:265] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# INFO 03-31 13:36:36 [weight_utils.py:281] Time spent downloading weights for unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit: 137.003600 seconds
# INFO 03-31 13:36:36 [weight_utils.py:315] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 03-31 13:37:32 [punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 03-31 13:37:33 [model_runner.py:1146] Model loading took 5.6446 GB and 194.962066 seconds
# INFO 03-31 13:37:45 [worker.py:267] Memory profiling takes 11.37 seconds
# INFO 03-31 13:37:45 [worker.py:267] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.59) = 8.76GiB
# INFO 03-31 13:37:45 [worker.py:267] model weights take 5.64GiB; non_torch_memory takes 0.03GiB; PyTorch activation peak memory takes 0.74GiB; the rest of the memory reserved for KV Cache is 2.35GiB.
# INFO 03-31 13:37:45 [executor_base.py:111] # cuda blocks: 1202, # CPU blocks: 1024
# INFO 03-31 13:37:45 [executor_base.py:116] Maximum concurrency for 512 tokens per request: 37.56x
# INFO 03-31 13:37:47 [model_runner.py:1442] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 23/23 [00:58<00:00,  2.56s/it]
# INFO 03-31 13:38:46 [model_runner.py:1570] Graph capturing finished in 59 secs, took 0.53 GiB
# INFO 03-31 13:38:46 [llm_engine.py:447] init engine (profile, create kv cache, warmup model) took 73.07 seconds
# tokenizer_config.json:   0%|          | 0.00/55.5k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# Not an error, but Unsloth cannot patch MLP layers with our manual autograd engine since either LoRA adapters
# are not enabled or a bias term (like in Qwen) is used.
# Unsloth 2025.3.19 patched 32 layers with 32 QKV layers, 32 O layers and 0 MLP layers.

# %%
import re
from datasets import load_dataset, Dataset

# Load and prep dataset
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

XML_COT_FORMAT = """\
<reasoning>
{reasoning}
</reasoning>
<answer>
{answer}
</answer>
"""

def extract_xml_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def extract_hash_answer(text: str) -> str | None:
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

# uncomment middle messages for 1-shot prompting
def get_gsm8k_questions(split = "train") -> Dataset:
    data = load_dataset('openai/gsm8k', 'main')[split] # type: ignore
    data = data.map(lambda x: { # type: ignore
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user', 'content': x['question']}
        ],
        'answer': extract_hash_answer(x['answer'])
    }) # type: ignore
    return data # type: ignore

dataset = get_gsm8k_questions()

# Reward functions
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_xml_answer(r) for r in responses]
    print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    return [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]

def int_reward_func(completions, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    extracted_responses = [extract_xml_answer(r) for r in responses]
    return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]

def strict_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def soft_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def count_xml(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1])*0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1)*0.001
    return count

def xmlcount_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    return [count_xml(c) for c in contents]
# Out:
# Map:   0%|          | 0/7473 [00:00<?, ? examples/s]

# %%
max_prompt_length = 256

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1,
    num_generations = 6,
    max_prompt_length = max_prompt_length,
    max_completion_length = max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 250,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",
)

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 7,473 | Num Epochs = 1 | Total steps = 250
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 1 x 1) = 1
#  "-____-"     Trainable parameters = 6,815,744/8,000,000,000 (0.09% trained)
# -------------------- Question:
# A concert ticket costs $40. Mr. Benson bought 12 tickets and received a 5% discount for every ticket bought that exceeds 10. How much did Mr. Benson pay in all?
# Answer:
# 476
# Response:
# Let's break down the problem:
#
# 1. The first 10 tickets will be full price ($40 each).
# 2. The next 2 tickets (12 - 10 = 2) receive a 5% discount.
#
# First, calculate the cost of the first 10 tickets:
# 10 tickets * $40 = $400
#
# Now, calculate the cost of the 2 tickets with the discount:
#
# The discount on each ticket is 5% of $40 = $2.
# The price of each discounted ticket is $40 - $2 = $38.
# 2 tickets * $38 = $76
#
# Now, add the cost of the full price tickets and the discounted tickets:
# $400 + $76 = $476
#
# <answer>
# Mr. Benson paid $476.
# </answer>
# Extracted:
# Mr. Benson paid $476.
#     <div>
#
#       <progress value='29' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 29/250 24:39 < 3:21:52, 0.02 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / xmlcount_reward_func</th>
#       <th>rewards / soft_format_reward_func</th>
#       <th>rewards / strict_format_reward_func</th>
#       <th>rewards / int_reward_func</th>
#       <th>rewards / correctness_reward_func</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.000000</td>
#       <td>-0.048000</td>
#       <td>0.117575</td>
#       <td>190.333344</td>
#       <td>0.000000</td>
#       <td>-0.048000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>248.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-0.140000</td>
#       <td>0.224072</td>
#       <td>201.833344</td>
#       <td>0.000006</td>
#       <td>-0.140000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.416667</td>
#       <td>1.020621</td>
#       <td>178.000000</td>
#       <td>0.000005</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.414667</td>
#       <td>1.025010</td>
#       <td>125.666672</td>
#       <td>0.000012</td>
#       <td>-0.002000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>1.226333</td>
#       <td>1.348182</td>
#       <td>204.500000</td>
#       <td>0.000005</td>
#       <td>-0.023667</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.021000</td>
#       <td>0.051439</td>
#       <td>221.333344</td>
#       <td>0.000006</td>
#       <td>0.021000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.416667</td>
#       <td>1.020621</td>
#       <td>158.500000</td>
#       <td>0.000008</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.833333</td>
#       <td>1.290995</td>
#       <td>163.833344</td>
#       <td>0.000007</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.166667</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>-0.082000</td>
#       <td>0.200858</td>
#       <td>229.166672</td>
#       <td>0.000005</td>
#       <td>-0.082000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>128.500000</td>
#       <td>0.000004</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>194.166672</td>
#       <td>0.000008</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>1.250000</td>
#       <td>1.369306</td>
#       <td>183.333344</td>
#       <td>0.000007</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.504000</td>
#       <td>1.000039</td>
#       <td>160.833344</td>
#       <td>0.000010</td>
#       <td>0.004000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.166667</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>0.854167</td>
#       <td>1.275776</td>
#       <td>243.166672</td>
#       <td>0.000005</td>
#       <td>0.020833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.166667</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.416667</td>
#       <td>1.020621</td>
#       <td>143.833344</td>
#       <td>0.000003</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>1.604000</td>
#       <td>1.369418</td>
#       <td>171.666672</td>
#       <td>0.000007</td>
#       <td>-0.062667</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.333333</td>
#       <td>1.333333</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>198.500000</td>
#       <td>0.000006</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>0.520833</td>
#       <td>0.988739</td>
#       <td>181.500000</td>
#       <td>0.000007</td>
#       <td>0.020833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.166667</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>172.166672</td>
#       <td>0.000008</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>0.436833</td>
#       <td>1.011899</td>
#       <td>178.166672</td>
#       <td>0.000014</td>
#       <td>0.020167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>0.006167</td>
#       <td>0.052423</td>
#       <td>94.500000</td>
#       <td>0.000014</td>
#       <td>0.006167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000000</td>
#       <td>1.354167</td>
#       <td>1.314384</td>
#       <td>126.000000</td>
#       <td>0.000032</td>
#       <td>0.020833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.333333</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>-0.040167</td>
#       <td>0.098388</td>
#       <td>172.000000</td>
#       <td>0.000014</td>
#       <td>-0.040167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>0.416667</td>
#       <td>1.020621</td>
#       <td>131.666672</td>
#       <td>0.000009</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000000</td>
#       <td>-0.061500</td>
#       <td>0.150644</td>
#       <td>207.333344</td>
#       <td>0.000023</td>
#       <td>-0.061500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.000000</td>
# -------------------- Question:
# Jane is trying to decide whether to buy a house or a trailer. A house costs $480,000 and a trailer costs $120,000. Each loan will be paid in monthly installments over 20 years. How much more is the monthly payment on the house compared to the trailer?
# Answer:
# 1500
# Response:
# To find the difference in the monthly payments, we need to calculate the monthly payments for each option and then subtract the trailer's payment from the house's payment.
#
# The formula to calculate the monthly payment (M) is:
#
# M = P x r x (1 + r)^n / [(1 + r)^n - 1]
#
# Where:
# - P is the principal loan amount
# - r is the monthly interest rate (annual interest rate / 12)
# - n is the number of payments (number of years * 12)
#
# For a house:
# - Principal amount (P) = $480,000
# - Annual interest rate = 5% (assuming a generic interest rate, which may vary)
# - Number of years = 20
# - Number of payments = 20 * 12 = 240
#
# Monthly interest rate (r) = 5% / 12 = 0.00417
#
# M_house = $480,000 * 0.00417 * (1 + 0.00417)^240 / [(1 + 0.00417)^240 - 1]
#
# After calculating, M_house ≈ $3,417.73
#
# For a trailer:
# - Principal amount (P) = $120,000
# - Annual interest rate
# Extracted:
# To find the difference in the monthly payments, we need to calculate the monthly payments for each option and then subtract the trailer's payment from the house's payment.
#
# The formula to calculate the monthly payment (M) is:
#
# M = P x r x (1 + r)^n / [(1 + r)^n - 1]
#
# Where:
# - P is the principal loan amount
# - r is the monthly interest rate (annual interest rate / 12)
# - n is the number of payments (number of years * 12)
#
# For a house:
# - Principal amount (P) = $480,000
# - Annual interest rate = 5% (assuming a generic interest rate, which may vary)
# - Number of years = 20
# - Number of payments = 20 * 12 = 240
#
# Monthly interest rate (r) = 5% / 12 = 0.00417
#
# M_house = $480,000 * 0.00417 * (1 + 0.00417)^240 / [(1 + 0.00417)^240 - 1]
#
# After calculating, M_house ≈ $3,417.73
#
# For a trailer:
# - Principal amount (P) = $120,000
# - Annual interest rate
# Unsloth: Will smartly offload gradients to save VRAM!
# -------------------- Question:
# Janet pays $40/hour for 3 hours per week of clarinet lessons and $28/hour for 5 hours a week of piano lessons. How much more does she spend on piano lessons than clarinet lessons in a year?
# Answer:
# 1040
# Response:
# Let's first calculate how much Janet spends on clarinet lessons per year.
# She pays $40/hour for 3 hours a week, so in a week she spends $40 * 3 = $120 on clarinet lessons.
# Since there are approximately 52 weeks in a year, she spends $120 * 52 = $6240 on clarinet lessons per year.
#
# Next, we'll calculate how much Janet spends on piano lessons per year. She pays $28/hour for 5 hours a week, so in a week she spends $28 * 5 = $140 on piano lessons.
# So, in a year she spends $140 * 52 = $7280 on piano lessons.
#
# The difference between the two is $7280 - $6240 = $1040.
#
# <answer> Janet spends $1040 more on piano lessons than clarinet lessons in a year.
# Extracted:
# Janet spends $1040 more on piano lessons than clarinet lessons in a year.
# -------------------- Question:
# Sabrina is collecting herbs to make a poultice for her grandmother. She needs twice as many basil leaves as sage leaves and 5 fewer sage leaves than verbena leaves. If she needs 12 basil leaves, how many leaves total does she need?
# Answer:
# 29
# Response:
# Let's break this problem down step by step.
#
# Since Sabrina needs twice as many basil leaves as sage leaves, and she needs 12 basil leaves, she must need 12 / 2 = 6 sage leaves.
#
# Since she needs 5 fewer sage leaves than verbena leaves, and she needs 6 sage leaves, she must need 6 + 5 = 11 verbena leaves.
#
# To find the total number of leaves, we need to add the number of basil, sage, and verbena leaves. The total number of leaves is 12 (basil) + 6 (sage) + 11 (verbena) = 29.
#
# Answer:
# <29>
# The total number of leaves Sabrina needs is 29.
# Extracted:
# Let's break this problem down step by step.
#
# Since Sabrina needs twice as many basil leaves as sage leaves, and she needs 12 basil leaves, she must need 12 / 2 = 6 sage leaves.
#
# Since she needs 5 fewer sage leaves than verbena leaves, and she needs 6 sage leaves, she must need 6 + 5 = 11 verbena leaves.
#
# To find the total number of leaves, we need to add the number of basil, sage, and verbena leaves. The total number of leaves is 12 (basil) + 6 (sage) + 11 (verbena) = 29.
#
# Answer:
# <29>
# The total number of leaves Sabrina needs is 29.
# -------------------- Question:
# Over the past five years, on July 4th, the high temperature for Washington, DC has been: 90 degrees in 2020, 90 degrees in 2019, 90 degrees in 2018, 79 degrees in 2017 and 71 degrees in 2016. What is the average temperature for July 4th in Washington, DC over the past 5 years?
# Answer:
# 84
# Response:
# To find the average temperature for July 4th in Washington, DC over the past 5 years, we need to add the temperatures and divide by the number of years.
#
# First, let's add the temperatures:
# 90 + 90 + 90 + 79 + 71 = 320
#
# Now, let's divide the sum by the number of years (5):
# 320 / 5 = 64
#
# So, the average temperature for July 4th in Washington, DC over the past 5 years is 64 degrees.
#
# </answer>
# Extracted:
# To find the average temperature for July 4th in Washington, DC over the past 5 years, we need to add the temperatures and divide by the number of years.
#
# First, let's add the temperatures:
# 90 + 90 + 90 + 79 + 71 = 320
#
# Now, let's divide the sum by the number of years (5):
# 320 / 5 = 64
#
# So, the average temperature for July 4th in Washington, DC over the past 5 years is 64 degrees.
# -------------------- Question:
# Rene can finish reading 30 pages in 60 minutes. Lulu can read 27 pages in 60 minutes and Cherry can read 25 pages in 60 minutes. If they have been reading for 240 minutes now, how many pages have they finished reading in total?
# Answer:
# 328
# Response:
# Let's analyze the situation step by step:
#
# Rene: 30 pages/60 minutes = 0.5 pages/minute, so in 240 minutes Rene will finish 0.5 * 240 = 120 pages.
# Lulu: 27 pages/60 minutes = 0.45 pages/minute, so in 240 minutes Lulu will finish 0.45 * 240 = 108 pages.
# Cherry: 25 pages/60 minutes = 0.4167 pages/minute, so in 240 minutes Cherry will finish 0.4167 * 240 = 100 pages.
#
# Now, let's add up the pages they finished: 120 + 108 + 100 = 328.
#
# <answer>328</answer>
# Extracted:
# 328
# -------------------- Question:
# Martin rings the small bell 4 times more than 1/3 as often as the big bell. If he rings both of them a combined total of 52 times, how many times does he ring the big bell?
# Answer:
# 36
# Response:
# Let's say the big bell is x.
#
# According to the problem, he rings the small bell 4 times more than 1/3 as often as the big bell. So, the small bell is (1/3)x + 4 times as often as the big bell.
#
# Since the big bell is x times, and the small bell is (1/3)x + 4 times as often as the big bell, in this context we can write the total as x + (1/3)x + 4 = 52.
#
# Now, we can simplify this to (4/3)x + 4 = 52.
#
# To isolate x, we first subtract 4 from both sides to get (4/3)x = 48.
#
# To get rid of the (4/3), we multiply both sides by 3/4 to get x = 36.
#
# There you have it. The big bell is 36 times as often as the big bell itself and thus the number was 36 times.
# Extracted:
# Let's say the big bell is x.
#
# According to the problem, he rings the small bell 4 times more than 1/3 as often as the big bell. So, the small bell is (1/3)x + 4 times as often as the big bell.
#
# Since the big bell is x times, and the small bell is (1/3)x + 4 times as often as the big bell, in this context we can write the total as x + (1/3)x + 4 = 52.
#
# Now, we can simplify this to (4/3)x + 4 = 52.
#
# To isolate x, we first subtract 4 from both sides to get (4/3)x = 48.
#
# To get rid of the (4/3), we multiply both sides by 3/4 to get x = 36.
#
# There you have it. The big bell is 36 times as often as the big bell itself and thus the number was 36 times.
# -------------------- Question:
# Bert fills out the daily crossword puzzle in the newspaper every day. He uses up a pencil to fill out the puzzles every two weeks. On average, it takes him 1050 words to use up a pencil. How many words are in each crossword puzzle on average?
# Answer:
# 75
# Response:
# Let's break it down step by step:
#
# reasoning
# Bert fills out a crossword puzzle every day, and it takes him two weeks to use up a pencil. Since there are 7 days in a week, Bert fills out a crossword puzzle 7 days/week * 2 weeks = 14 days per pencil.
#
# He uses up a pencil after completing 1050 words. To find out how many words are in each crossword puzzle, we need to divide the total number of words used by the number of puzzles completed with that pencil.
#
# answer
#
# words_per_puzzle = 1050 words / 14 puzzles
# words_per_puzzle = 75
#
# So, on average, each crossword puzzle has 75 words.
# Extracted:
# Let's break it down step by step:
#
# reasoning
# Bert fills out a crossword puzzle every day, and it takes him two weeks to use up a pencil. Since there are 7 days in a week, Bert fills out a crossword puzzle 7 days/week * 2 weeks = 14 days per pencil.
#
# He uses up a pencil after completing 1050 words. To find out how many words are in each crossword puzzle, we need to divide the total number of words used by the number of puzzles completed with that pencil.
#
# answer
#
# words_per_puzzle = 1050 words / 14 puzzles
# words_per_puzzle = 75
#
# So, on average, each crossword puzzle has 75 words.
# -------------------- Question:
# Matt can make a batch of a dozen cookies using 2 pounds of flour.  He uses 4 bags of flour each weighing 5 pounds.  If Jim eats 15 cookies how many cookies are left?
# Answer:
# 105
# Response:
# To find out how many cookies Matt can make, we need to find out how much flour he has and how many cookies he can make from that amount.
#
# First, we need to find out how much flour Matt has: 4 bags * 5 pounds = 20 pounds.
#
# Since Matt can make a batch of a dozen (12) cookies using 2 pounds of flour, the amount of cookies he can make from 20 pounds of flour is 20 / 2 * 12 = 120 cookies (because he can make 12 cookies with 2 pounds, so with 20 pounds, he can make 10 sets of 12 cookies).
#
# However, since Jim eats 15 cookies, we need to subtract that from the total number of cookies. So we do 120 - 15.
#
# 120 - 15 = 105
#
# There are 105 cookies left.
# Extracted:
# To find out how many cookies Matt can make, we need to find out how much flour he has and how many cookies he can make from that amount.
#
# First, we need to find out how much flour Matt has: 4 bags * 5 pounds = 20 pounds.
#
# Since Matt can make a batch of a dozen (12) cookies using 2 pounds of flour, the amount of cookies he can make from 20 pounds of flour is 20 / 2 * 12 = 120 cookies (because he can make 12 cookies with 2 pounds, so with 20 pounds, he can make 10 sets of 12 cookies).
#
# However, since Jim eats 15 cookies, we need to subtract that from the total number of cookies. So we do 120 - 15.
#
# 120 - 15 = 105
#
# There are 105 cookies left.
# -------------------- Question:
# James decides to build a tin house by collecting 500 tins in a week. On the first day, he collects 50 tins. On the second day, he manages to collect 3 times that number. On the third day, he collects 50 tins fewer than the number he collected on the second day. If he collects an equal number of tins on the remaining days of the week, what's the number of tins he collected each day for the rest of the week?
# Answer:
# 50
# Response:
# Let's break down James's tin collection day by day.
#
# On the first day, James collects 50 tins.
#
# On the second day, he collects 3 times the number of tins he collected on the first day, so he collects 50 * 3 = 150 tins.
#
# On the third day, he collects 50 tins fewer than the number he collected on the second day, so he collects 150 - 50 = 100 tins.
#
# Now, let's calculate the total number of tins James collects in the first three days: 50 + 150 + 100 = 300 tins.
#
# Since James needs 500 tins in total and has collected 300 tins in the first three days, he needs to collect 500 - 300 = 200 tins in the remaining 4 days.
#
# Since he collects an equal number of tins on the remaining days of the week, we can divide the remaining tins (200) by the number of remaining days (4): 200 / 4 = 50.
#
# So, James collects 50 tins each day for the rest of the week.
# Extracted:
# Let's break down James's tin collection day by day.
#
# On the first day, James collects 50 tins.
#
# On the second day, he collects 3 times the number of tins he collected on the first day, so he collects 50 * 3 = 150 tins.
#
# On the third day, he collects 50 tins fewer than the number he collected on the second day, so he collects 150 - 50 = 100 tins.
#
# Now, let's calculate the total number of tins James collects in the first three days: 50 + 150 + 100 = 300 tins.
#
# Since James needs 500 tins in total and has collected 300 tins in the first three days, he needs to collect 500 - 300 = 200 tins in the remaining 4 days.
#
# Since he collects an equal number of tins on the remaining days of the week, we can divide the remaining tins (200) by the number of remaining days (4): 200 / 4 = 50.
#
# So, James collects 50 tins each day for the rest of the week.
# -------------------- Question:
# A jar of jellybeans has 14 blue jellybeans, 26 purple jellybeans and 40 orange jellybeans. If there are 200 jellybeans in the jar, how many are there of the red color?
# Answer:
# 120
# Response:
# We know that there are a total of 200 jellybeans in the jar, and the sum of the blue, purple, and orange jellybeans are as follows: 14 + 26 + 40 = 80.
#
# To find the number of red jellybeans, we need to subtract the total amount of known jellybeans from the total number of jellybeans in the jar.
#
# red_jellybeans = total_jellybeans - (blue + purple + orange)
#               = 200 - 80
#               = 120
#
# So, there are 120 red jellybeans in the jar.
# Extracted:
# We know that there are a total of 200 jellybeans in the jar, and the sum of the blue, purple, and orange jellybeans are as follows: 14 + 26 + 40 = 80.
#
# To find the number of red jellybeans, we need to subtract the total amount of known jellybeans from the total number of jellybeans in the jar.
#
# red_jellybeans = total_jellybeans - (blue + purple + orange)
#               = 200 - 80
#               = 120
#
# So, there are 120 red jellybeans in the jar.
# -------------------- Question:
# Five adults and two children go to see a movie and buy $12 worth of concessions. The total cost of their trip is $76. If each child's ticket is $7, how much, in dollars, are the adult tickets?
# Answer:
# 10
# Response:
# Let's break down the given information:
#
# - Total cost of the trip: $76
# - Cost of concessions: $12
# - Total number of adults: 5
# - Number of children: 2
# - Child's ticket price: $7
#
# First, we need to subtract the cost of concessions from the total cost to find out how much was spent on tickets.
# Total cost of tickets = Total cost of trip - Cost of concessions
# Total cost of tickets = $76 - $12
# Total cost of tickets = $64
#
# Since there are 7 people in total (5 adults + 2 children), and each ticket costs different prices ($7 for children and x for adults), we can set up an equation.
#
# Let's represent the cost of an adult ticket as 'x'. The total cost of adult tickets is 5x, and the total cost of children's tickets is 2*$7. The equation can be formed as follows:
#
# 5x + 2*7 = 64
#
# Simplifying the equation:
# 5x + 14 = 64
#
# Now, we need to isolate the variable 'x'. Subtracting 14 from both sides:
# 5x = 64 - 14
# 5x = 50
#
# Now,
# Extracted:
# Let's break down the given information:
#
# - Total cost of the trip: $76
# - Cost of concessions: $12
# - Total number of adults: 5
# - Number of children: 2
# - Child's ticket price: $7
#
# First, we need to subtract the cost of concessions from the total cost to find out how much was spent on tickets.
# Total cost of tickets = Total cost of trip - Cost of concessions
# Total cost of tickets = $76 - $12
# Total cost of tickets = $64
#
# Since there are 7 people in total (5 adults + 2 children), and each ticket costs different prices ($7 for children and x for adults), we can set up an equation.
#
# Let's represent the cost of an adult ticket as 'x'. The total cost of adult tickets is 5x, and the total cost of children's tickets is 2*$7. The equation can be formed as follows:
#
# 5x + 2*7 = 64
#
# Simplifying the equation:
# 5x + 14 = 64
#
# Now, we need to isolate the variable 'x'. Subtracting 14 from both sides:
# 5x = 64 - 14
# 5x = 50
#
# Now,
# -------------------- Question:
# Janelle had 26 green marbles. Then she bought 6 bags of blue marbles. There were 10 marbles in each bag.  She created a gift of 6 green marbles and 8 blue marbles and gave it to a friend. How many marbles does Janelle have now?
# Answer:
# 72
# Response:
# Let's break this problem down step by step:
#
# 1. Janelle initially had 26 green marbles.
# 2. She bought 6 bags of blue marbles. Each bag had 10 marbles, so the total number of blue marbles she bought is 6 bags * 10 marbles/bag = 60 blue marbles.
# 3. Now, Janelle has 26 green marbles + 60 blue marbles = 86 marbles in total.
# 4. She gave 6 green marbles and 8 blue marbles to her friend. The total number of marbles she gave away is 6 + 8 = 14 marbles.
# 5. The number of marbles she has left is 86 - 14 = 72.
#
# <answer>
# Janelle now has 72 marbles.
# Extracted:
# Janelle now has 72 marbles.
# -------------------- Question:
# Every day in a week, Siena bookmarks 30 website pages from the research she does on her browser. If Siena has 400 bookmarked pages on her bookmarks library now, how many pages will she have in her bookmarks library at the end of March?
# Answer:
# 1330
# Response:
# To find out how many pages Siena will have in her bookmarks library at the end of March, we need to know how many days are in March. March has 31 days.
#
# Since Siena bookmarks 30 pages every day, the total number of pages she will bookmark in March is:
# 30 pages/day * 31 days = 930 pages
#
# We also know that Siena already has 400 pages bookmarked. To find the total number of pages she will have in her bookmarks library at the end of March, we add the number of pages she bookmarked in March to the number of pages she already has:
# 930 pages + 400 pages = 1330 pages
#
# <answer>1330</answer>
# Extracted:
# 1330
# -------------------- Question:
# An old pirate wants to leave his treasure on an island. He has 3500 gold coins. He wants to spread this equally across 5 chests. Additionally, he will put a total of 500 silver coins and twice as many bronze coins as silver, all distributed equally across the chests. How many coins in total will be in each chest?
# Answer:
# 1000
# Response:
# To find the number of coins in each chest, we need to first distribute the gold coins, then the silver coins, and finally the bronze coins.
#
# The old pirate has 3500 gold coins, and he wants to distribute them equally across 5 chests, so we divide the total number of gold coins by 5:
# 3500 / 5 = 700 gold coins in each chest.
#
# The total number of silver coins is 500, and it will be distributed equally across 5 chests:
# 500 / 5 = 100 silver coins in each chest.
#
# The old pirate will also put twice as many bronze coins as silver coins. Since there are 500 silver coins, there will be 2 x 500 = 1000 bronze coins. Now, we distribute them equally across 5 chests:
# 1000 / 5 = 200 bronze coins in each chest.
#
# Now we need to find the total number of coins in each chest. We add the number of gold, silver, and bronze coins in each chest:
# 700 (gold) + 100 (silver) + 200 (bronze) = 1000.
#
# <reasoning>
# To find the total number of coins in each chest, we first distribute each type of coin across 5 chests.
# Extracted:
# To find the number of coins in each chest, we need to first distribute the gold coins, then the silver coins, and finally the bronze coins.
#
# The old pirate has 3500 gold coins, and he wants to distribute them equally across 5 chests, so we divide the total number of gold coins by 5:
# 3500 / 5 = 700 gold coins in each chest.
#
# The total number of silver coins is 500, and it will be distributed equally across 5 chests:
# 500 / 5 = 100 silver coins in each chest.
#
# The old pirate will also put twice as many bronze coins as silver coins. Since there are 500 silver coins, there will be 2 x 500 = 1000 bronze coins. Now, we distribute them equally across 5 chests:
# 1000 / 5 = 200 bronze coins in each chest.
#
# Now we need to find the total number of coins in each chest. We add the number of gold, silver, and bronze coins in each chest:
# 700 (gold) + 100 (silver) + 200 (bronze) = 1000.
#
# <reasoning>
# To find the total number of coins in each chest, we first distribute each type of coin across 5 chests.
# -------------------- Question:
# Ephraim has two machines that make necklaces for his store. On Sunday the first machine made 45 necklaces. The second machine made 2.4 times as many necklaces as the first machine. How many necklaces were made in total on Sunday?
# Answer:
# 153
# Response:
# To find the total number of necklaces made on Sunday, we need to add the number of necklaces made by both machines.
#
# The first machine made 45 necklaces.
#
# The second machine made 2.4 times as many necklaces as the first machine, so the second machine made 2.4 * 45 = 108 necklaces.
#
# The total number of necklaces made on Sunday is 45 (first machine) + 108 (second machine) = 153.
#
# <answer> 153 </answer>
# Extracted:
# 153
# -------------------- Question:
# Zach baked cookies for a bake sale. On Monday he baked 32 cookies. On Tuesday he ran out of sugar and could only bake half of the number of cookies he baked the day before. On Wednesday he baked three times the number of cookies he did on Tuesday, but his brother ate 4 of those cookies. How many cookies did he have at the end of the three days?
# Answer:
# 92
# Response:
# Let's break down the situation step by step:
#
# On Monday, Zach baked 32 cookies.
#
# On Tuesday, he baked half of the number of cookies he baked the day before. Since he baked 32 cookies on Monday, he baked 32 / 2 = 16 cookies on Tuesday.
#
# On Wednesday, he baked three times the number of cookies he did on Tuesday. So he baked 3 x 16 = 48 cookies, but then his brother ate 4 cookies. This means he ended up with 48 - 4 = 44 cookies on Wednesday.
#
# To find the total number of cookies at the end of the three days, we need to add the cookies from each day:
#
# Monday: 32 cookies
# Tuesday: 16 cookies
# Wednesday: 44 cookies
# Total: 32 + 16 + 44 = 92 cookies
#
# <answer>92</answer>
# Extracted:
# 92
# -------------------- Question:
# Mark and James need a total of 14 dice that are 12 sided to play their game.  Mark has a bag of 10 dice and 60% of them are 12 sided.  James has a bag of 8 dice and 75% of them are 12 sided.  How many dice will the boys need to buy to play their game?
# Answer:
# 2
# Response:
# To determine how many dice Mark and James need to buy, first calculate how many 12-sided dice they have in total, then subtract that number from the total number of 12-sided dice they need.
#
# Mark has a bag of 10 dice, and 60% of them are 12-sided.
# 60% = 60 / 100 = 0.6
# Number of 12-sided dice Mark has: 10 * 0.6 = 6
#
# James has a bag of 8 dice, and 75% of them are 12-sided.
# 75% = 75 / 100 = 0.75
# Number of 12-sided dice James has: 8 * 0.75 = 6
#
# Total number of 12-sided dice Mark and James have: 6 + 6 = 12
# Total number of 12-sided dice needed: 14
#
# Since Mark and James have 12 out of the 14 needed dice, to play their game, they will need to buy 2 additional dice.
# Extracted:
# To determine how many dice Mark and James need to buy, first calculate how many 12-sided dice they have in total, then subtract that number from the total number of 12-sided dice they need.
#
# Mark has a bag of 10 dice, and 60% of them are 12-sided.
# 60% = 60 / 100 = 0.6
# Number of 12-sided dice Mark has: 10 * 0.6 = 6
#
# James has a bag of 8 dice, and 75% of them are 12-sided.
# 75% = 75 / 100 = 0.75
# Number of 12-sided dice James has: 8 * 0.75 = 6
#
# Total number of 12-sided dice Mark and James have: 6 + 6 = 12
# Total number of 12-sided dice needed: 14
#
# Since Mark and James have 12 out of the 14 needed dice, to play their game, they will need to buy 2 additional dice.
# -------------------- Question:
# Erin counts six trolls hiding by the path in the forest, 6 less than four times that number of trolls hiding under the bridge, and half as many trolls hiding in the plains as under the bridge. How many trolls did she count in total?
# Answer:
# 33
# Response:
# Let's analyze the information given:
#
# Erin counts six trolls hiding by the path in the forest.
# Let's call the number of trolls under the bridge, "x".
#
# The number of trolls hiding by the path in the forest is 6 less than four times the number hiding under the bridge, so it can be represented as: 4x - 6 = 6
#
# 4x = 6 + 6
# 4x = 12
#
# x = 12/4
# x = 3
#
# There are 3 trolls hiding under the bridge.
#
# There are half as many trolls hiding in the plains as under the bridge, so there are 3/2 = 1.5 trolls in the plains. Since we can't have a fraction of a troll, Erin counted 1 troll.
#
# The total number of trolls counted is 6 (by the path), 3 (under the bridge), and 1 (in the plains).
# Extracted:
# Let's analyze the information given:
#
# Erin counts six trolls hiding by the path in the forest.
# Let's call the number of trolls under the bridge, "x".
#
# The number of trolls hiding by the path in the forest is 6 less than four times the number hiding under the bridge, so it can be represented as: 4x - 6 = 6
#
# 4x = 6 + 6
# 4x = 12
#
# x = 12/4
# x = 3
#
# There are 3 trolls hiding under the bridge.
#
# There are half as many trolls hiding in the plains as under the bridge, so there are 3/2 = 1.5 trolls in the plains. Since we can't have a fraction of a troll, Erin counted 1 troll.
#
# The total number of trolls counted is 6 (by the path), 3 (under the bridge), and 1 (in the plains).
# -------------------- Question:
# Karen packs peanut butter sandwiches in her daughter's lunch 2 randomly chosen days of the week. The other 3 school days, she packs a ham sandwich. She packs a piece of cake on one randomly chosen day and cookies the other four days. What is the probability, expressed as a percentage, that Karen packs a ham sandwich and cake on the same day?
# Answer:
# 12
# Response:
# There are a total of 5 days in a school week that she packs lunch.  For ham sandwich and cake to be packed on the same day, there is one specific combination each week out of the total of $5 \cdot 5 = 25$ possible combinations of days when a ham sandwich or cake is packed.  This is because there are 5 days she could pack a ham sandwich, and for each of those 5 days, there are 5 days she could pack a cake.
#
# The probability of ham sandwich and cake being packed on the same day is $\frac{1}{25}$, which is $\frac{1}{5}$ times $ \frac{1}{5}$. Converting this to a percentage, the probability is $\boxed{2\%}$.
# Extracted:
# There are a total of 5 days in a school week that she packs lunch.  For ham sandwich and cake to be packed on the same day, there is one specific combination each week out of the total of $5 \cdot 5 = 25$ possible combinations of days when a ham sandwich or cake is packed.  This is because there are 5 days she could pack a ham sandwich, and for each of those 5 days, there are 5 days she could pack a cake.
#
# The probability of ham sandwich and cake being packed on the same day is $\frac{1}{25}$, which is $\frac{1}{5}$ times $ \frac{1}{5}$. Converting this to a percentage, the probability is $\boxed{2\%}$.
# -------------------- Question:
# A four-layer pyramid is being built with each layer having three times as many sandstone blocks as the layer above it. The top layer is a single block. How many sandstone blocks are in the pyramid?
# Answer:
# 40
# Response:
# Each layer has three times as many blocks as the layer above it. The bottom layer will therefore be 3^3 = 3*3*3 = 27 blocks, the layer above that will have 3 * 27 = 81 blocks, then the layer above that will have 3 * 81 = 243 and the top will have 3 * 243 = 729. So adding the top and all the associated layers, 729 + 243 + 81 + 27 = 1080 sandstone blocks are in the pyramid.
#
# </answer>
# 1080
# Extracted:
# Each layer has three times as many blocks as the layer above it. The bottom layer will therefore be 3^3 = 3*3*3 = 27 blocks, the layer above that will have 3 * 27 = 81 blocks, then the layer above that will have 3 * 81 = 243 and the top will have 3 * 243 = 729. So adding the top and all the associated layers, 729 + 243 + 81 + 27 = 1080 sandstone blocks are in the pyramid.
# -------------------- Question:
# The cost of Joe's new HVAC system is $20,000.  It includes 2 conditioning zones, each with 5 vents.  In dollars, what is the cost of the system per vent?
# Answer:
# 2,000
# Response:
# <There are a total of 2 zones, with each zone having 5 vents, making a total of 2 * 5 = 10 vents. To find the total cost per vent, we can divide the total cost of the system by the total number of vents.>
#
# <answer> $20,000 / 10 = $2,000 per vent. </answer>
# Extracted:
# $20,000 / 10 = $2,000 per vent.
# -------------------- Question:
# Trent walked 4 blocks from his house to the bus stop. He rode the bus 7 blocks to the library. Later, he came home the same way. How many blocks did Trent travel in all?
# Answer:
# 22
# Response:
# To find the total number of blocks Trent traveled, we need to calculate the total distance to the library and then double it to account for the return trip.
#
# Trent walked 4 blocks to the bus stop and rode the bus 7 blocks. The total distance to the library is 4 + 7 = 11 blocks.
#
# Since he came home the same way, we multiply the total distance to the library by 2 to get the round-trip distance. 11 blocks * 2 = 22 blocks.
#
# <answer> 22 </answer>
# Extracted:
# 22
# -------------------- Question:
# Lee had $10 and his friend had $8. They went to a restaurant where they ordered chicken wings for $6 and a chicken salad for $4. They also got 2 sodas for $1.00 each. The tax came to $3. How much change should they have received in total?
# Answer:
# 3
# Response:
# To find the total cost of their order, we need to add the cost of the chicken wings, the chicken salad, and the sodas.
#
# Total cost of chicken wings = $6
# Total cost of chicken salad = $4
# Total cost of sodas = 2 * $1 = $2
# Total cost of food and drinks = $6 + $4 + $2 = $12
#
# Adding the tax, the total amount they need to pay = $12 + $3 = $15
#
# They had a total of $10 + $8 = $18.
#
# To find the total change they should receive, we subtract the total amount they need to pay from the total amount they had:
#
# Total change = $18 - $15 = $3
#
# <reasoning>
# Calculate the total cost of food and drinks, then add the tax to get the total amount to be paid. Subtract this from the total amount they had to get the change.
# </reasoning>
# <answer>
# $3
# </answer>
# Extracted:
# $3
# -------------------- Question:
# Andy walks 50 meters from his house to school. After school, he comes back to the house and goes to the market. If he walks 140 meters in total, how many meters is the distance between the house and the market?
# Answer:
# 40
# Response:
# Reasoning
# - Andy walks 50 meters from his house to school.
# - Then, he walks the same distance of 50 meters back to the house.
# - After that, he walks an unknown distance from the house to the market.
# - The total distance covered is 140 meters.
#
# We know that the distance from the house to the school and the distance from the school to the house is a total of 50 + 50 = 100 meters.
# So, the distance from the house to the market = total distance - distance from house to school - distance from school to house
# This implies that the distance from the house to the market = 140 - 100 = 40 meters.
# Answer
# 40 meters.
# Extracted:
# Reasoning
# - Andy walks 50 meters from his house to school.
# - Then, he walks the same distance of 50 meters back to the house.
# - After that, he walks an unknown distance from the house to the market.
# - The total distance covered is 140 meters.
#
# We know that the distance from the house to the school and the distance from the school to the house is a total of 50 + 50 = 100 meters.
# So, the distance from the house to the market = total distance - distance from house to school - distance from school to house
# This implies that the distance from the house to the market = 140 - 100 = 40 meters.
# Answer
# 40 meters.
# -------------------- Question:
# Tara has been planning to buy a laptop which costs $1000. A computer shop accepts payment in installments of $65 per month provided that a 20% down payment is made. If Tara wants to pay an additional $20 for the down payment, how much will her balance be after paying for 4 months?
# Answer:
# 520
# Response:
# reasoning
# First, Tara's down payment is 20% of the cost of the laptop, which is 0.2 * $1000 = $200. Since she wants to pay an additional $20, her total down payment will be $200 + $20 = $220. This leaves her with $1000 - $220 = $780 remaining balance to be paid through installments.
#
# The monthly installment is $65 and she will be paying this for 4 months. So, the total amount she pays through installments is $65 * 4 = $260.
#
# Now, to find the remaining balance after 4 months, we subtract the total paid through installments from the remaining balance: $780 - $260 = $520.
#
# However, the question asks how much her balance will be after paying for 4 months. The balance after 4 months will be'remaining balance after 4 months = $780 - $260' from her down payment. So, her balance is $520.
#
# Since $520 is the payment made from the initial remaining balance when she started paying installments, her account would have $780 - $520 = $260.
# Extracted:
# reasoning
# First, Tara's down payment is 20% of the cost of the laptop, which is 0.2 * $1000 = $200. Since she wants to pay an additional $20, her total down payment will be $200 + $20 = $220. This leaves her with $1000 - $220 = $780 remaining balance to be paid through installments.
#
# The monthly installment is $65 and she will be paying this for 4 months. So, the total amount she pays through installments is $65 * 4 = $260.
#
# Now, to find the remaining balance after 4 months, we subtract the total paid through installments from the remaining balance: $780 - $260 = $520.
#
# However, the question asks how much her balance will be after paying for 4 months. The balance after 4 months will be'remaining balance after 4 months = $780 - $260' from her down payment. So, her balance is $520.
#
# Since $520 is the payment made from the initial remaining balance when she started paying installments, her account would have $780 - $520 = $260.
# -------------------- Question:
# Bill picked 50 apples from the orchard with his wife and two children.  He sends each of his kids to school with 3 apples for their two favorite teachers.  His wife Jill bakes two apple pies, using 10 apples per pie. How many apples does Bill have left?
# Answer:
# 24
# Response:
# Let's break down the information:
#
# - Bill picked 50 apples.
# - Each of his 2 kids takes 3 apples for their teachers, which is 2 * 3 = 6 apples.
# - The kids took 6 apples, so now Bill has 50 - 6 = 44 apples left.
# - Jill uses 10 apples each for 2 pies, which is 2 * 10 = 20 apples.
# - After Jill uses the apples, Bill has 44 - 20 = 24 apples left.
#
# <answer> 24. </answer>
# Extracted:
# 24.
# -------------------- Question:
# Each year Dani gets 4 pairs of two pants each as pay winning the best Amazon buyer of the season. If he initially had 50 pants, calculate the number of pants he'll have in 5 years.
# Answer:
# 90
# Response:
# Let's break this down step by step:
#
# Initially, Dani has 50 pairs of pants, which means he has 50 * 2 = 100 pants.
#
# Each year, he gets 4 pairs of two pants, which is 4 * 2 = 8 pants.
#
# To find out how many pants Dani will have after 5 years, we need to add the number of pants he gets each year to his initial number of pants and account for the fact that he already has pants.
#
# Year 0 (initial): 100 pants
# Year 1: 100 + 8 = 108 pants
# Year 2: 108 + 8 = 116 pants
# Year 3: 116 + 8 = 124 pants
# Year 4: 124 + 8 = 132 pants
# Year 5: 132 + 8 = 140 pants
#
# So, after 5 years, Dani will have 140 pants.
# Extracted:
# Let's break this down step by step:
#
# Initially, Dani has 50 pairs of pants, which means he has 50 * 2 = 100 pants.
#
# Each year, he gets 4 pairs of two pants, which is 4 * 2 = 8 pants.
#
# To find out how many pants Dani will have after 5 years, we need to add the number of pants he gets each year to his initial number of pants and account for the fact that he already has pants.
#
# Year 0 (initial): 100 pants
# Year 1: 100 + 8 = 108 pants
# Year 2: 108 + 8 = 116 pants
# Year 3: 116 + 8 = 124 pants
# Year 4: 124 + 8 = 132 pants
# Year 5: 132 + 8 = 140 pants
#
# So, after 5 years, Dani will have 140 pants.
# -------------------- Question:
# Jessica’s class is going to a farm for a field trip. The school will bring all 35 students in the class plus 4 adult chaperones. The farm entrance fee for students costs $5 and $6 for adults. How much will the school pay for the farm entrance in all?
# Answer:
# 199
# Response:
# To find the total cost of the farm entrance, we need to add the cost of the students' entrance fees to the cost of the adults' entrance fees.
#
# The cost of the students' entrance fees will be 35 * $5 = $175.
# The cost of the adults' entrance fees will be 4 * $6 = $24.
# Adding the two amounts together, the total cost will be $175 + $24 = $199.
#
# <answer> $199 </answer>
# Extracted:
# $199
#     <div>
#
#       <progress value='31' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 31/250 26:12 < 3:17:54, 0.02 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / xmlcount_reward_func</th>
#       <th>rewards / soft_format_reward_func</th>
#       <th>rewards / strict_format_reward_func</th>
#       <th>rewards / int_reward_func</th>
#       <th>rewards / correctness_reward_func</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.000000</td>
#       <td>-0.048000</td>
#       <td>0.117575</td>
#       <td>190.333344</td>
#       <td>0.000000</td>
#       <td>-0.048000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>248.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-0.140000</td>
#       <td>0.224072</td>
#       <td>201.833344</td>
#       <td>0.000006</td>
#       <td>-0.140000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.416667</td>
#       <td>1.020621</td>
#       <td>178.000000</td>
#       <td>0.000005</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.414667</td>
#       <td>1.025010</td>
#       <td>125.666672</td>
#       <td>0.000012</td>
#       <td>-0.002000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>1.226333</td>
#       <td>1.348182</td>
#       <td>204.500000</td>
#       <td>0.000005</td>
#       <td>-0.023667</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.021000</td>
#       <td>0.051439</td>
#       <td>221.333344</td>
#       <td>0.000006</td>
#       <td>0.021000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.416667</td>
#       <td>1.020621</td>
#       <td>158.500000</td>
#       <td>0.000008</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.833333</td>
#       <td>1.290995</td>
#       <td>163.833344</td>
#       <td>0.000007</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.166667</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>-0.082000</td>
#       <td>0.200858</td>
#       <td>229.166672</td>
#       <td>0.000005</td>
#       <td>-0.082000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>128.500000</td>
#       <td>0.000004</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>194.166672</td>
#       <td>0.000008</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>1.250000</td>
#       <td>1.369306</td>
#       <td>183.333344</td>
#       <td>0.000007</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.504000</td>
#       <td>1.000039</td>
#       <td>160.833344</td>
#       <td>0.000010</td>
#       <td>0.004000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.166667</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>0.854167</td>
#       <td>1.275776</td>
#       <td>243.166672</td>
#       <td>0.000005</td>
#       <td>0.020833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.166667</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.416667</td>
#       <td>1.020621</td>
#       <td>143.833344</td>
#       <td>0.000003</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>1.604000</td>
#       <td>1.369418</td>
#       <td>171.666672</td>
#       <td>0.000007</td>
#       <td>-0.062667</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.333333</td>
#       <td>1.333333</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>198.500000</td>
#       <td>0.000006</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>0.520833</td>
#       <td>0.988739</td>
#       <td>181.500000</td>
#       <td>0.000007</td>
#       <td>0.020833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.166667</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>172.166672</td>
#       <td>0.000008</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>0.436833</td>
#       <td>1.011899</td>
#       <td>178.166672</td>
#       <td>0.000014</td>
#       <td>0.020167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>0.006167</td>
#       <td>0.052423</td>
#       <td>94.500000</td>
#       <td>0.000014</td>
#       <td>0.006167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000000</td>
#       <td>1.354167</td>
#       <td>1.314384</td>
#       <td>126.000000</td>
#       <td>0.000032</td>
#       <td>0.020833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.333333</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>-0.040167</td>
#       <td>0.098388</td>
#       <td>172.000000</td>
#       <td>0.000014</td>
#       <td>-0.040167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>0.416667</td>
#       <td>1.020621</td>
#       <td>131.666672</td>
#       <td>0.000009</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.083333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000000</td>
#       <td>-0.061500</td>
#       <td>0.150644</td>
#       <td>207.333344</td>
#       <td>0.000023</td>
#       <td>-0.061500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.000000</td>
# -------------------- Question:
# Ellen is baking bread. It takes 3 hours to rise 1 ball of dough, and then another 2 hours to bake it. If she makes 4 balls of dough one after another and then bakes them one after another when they're done rising, how many hours will it take?
# Answer:
# 20
# Response:
# To find the total time it takes, Ellen needs to calculate the rising time and baking time separately.
#
# For rising 4 balls of dough, each taking 3 hours, she needs 4 * 3 = 12 hours.
#
# For baking 4 balls of dough, each taking 2 hours, she needs 4 * 2 = 8 hours.
#
# She can rise and bake one ball of dough at the same time. So the total time will be 12 (rising) + 8 (baking) = 20 hours.
#
# The answer is 20.
# Extracted:
# To find the total time it takes, Ellen needs to calculate the rising time and baking time separately.
#
# For rising 4 balls of dough, each taking 3 hours, she needs 4 * 3 = 12 hours.
#
# For baking 4 balls of dough, each taking 2 hours, she needs 4 * 2 = 8 hours.
#
# She can rise and bake one ball of dough at the same time. So the total time will be 12 (rising) + 8 (baking) = 20 hours.
#
# The answer is 20.

# %%
from trl import GRPOConfig

training_args = GRPOConfig(
    use_vllm = True,
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    bf16 = is_bfloat16_supported(),
    fp16 = not is_bfloat16_supported(),
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1,
    num_generations = 6,
    max_prompt_length = 256,
    max_completion_length = 200,
    max_steps = 250,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none",
    output_dir = "outputs",
)

# %%
from trl import GRPOTrainer

trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 7,473 | Num Epochs = 1 | Total steps = 250
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 1 x 1) = 1
#  "-____-"     Trainable parameters = 6,815,744/8,000,000,000 (0.09% trained)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c700d5aa279f> in <cell line: 0>()
#      14     train_dataset = dataset,
#      15 )
# ---> 16 trainer.train()
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243                 hf_hub_utils.enable_progress_bars()
#    2244         else:
# -> 2245             return inner_training_loop(
#    2246                 args=args,
#    2247                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/unsloth/models/llama.py in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# /usr/local/lib/python3.11/dist-packages/unsloth/models/_utils.py in _unsloth_training_step(self, model, inputs, num_items_in_batch)
#
# /content/unsloth_compiled_cache/UnslothGRPOTrainer.py in _prepare_inputs(self, inputs)
#     990                         # Repeat each value in the column for `num_generations` times
#     991                         reward_kwargs[key].extend([example[key]] * self.num_generations)
# --> 992                 output_reward_func = reward_func(prompts=prompts, completions=completions, **reward_kwargs)
#     993                 rewards_per_func[:, i] = torch.tensor(output_reward_func, dtype=torch.float32, device=device)
#     994
#
# <ipython-input-5-ebf6e8a4110c> in int_reward_func(completions, **kwargs)
#      13 def int_reward_func(completions, **kwargs) -> list[float]:
#      14     responses = [completion[0]['content'] for completion in completions]
# ---> 15     extracted_responses = [extract_xml_answer(r) for r in responses]
#      16     return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]
#      17
#
# <ipython-input-5-ebf6e8a4110c> in <listcomp>(.0)
#      13 def int_reward_func(completions, **kwargs) -> list[float]:
#      14     responses = [completion[0]['content'] for completion in completions]
# ---> 15     extracted_responses = [extract_xml_answer(r) for r in responses]
#      16     return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]
#      17
#
# <ipython-input-5-ebf6e8a4110c> in extract_xml_answer(text)
#       1 def extract_xml_answer(text: str) -> str:
# ----> 2     answer = text.split("")[-1]
#       3     answer = answer.split("")[0]
#       4     return answer.strip()
#       5
#
# ValueError: empty separator

# %%
from vllm import SamplingParams

# %%
query = "which is bigger 9.11 or 9.9?"

text = tokenizer.apply_chat_template([
    {"role" : "user", "content" : query},
], tokenize = False, add_generation_prompt = True)


output = model.fast_generate([text],
                             sampling_params = SamplingParams(
                                 temperature = 0.8,
                                 top_p = 0.95,
                                 max_tokens = 1024),
                             lora_request = None
                             )[0].outputs[0].text

print(output)

# %%
model.save_lora("grpo_saved_lora")

# %%
# Model with LoRA weights

query = "which is bigger 9.11 or 9.9?"

text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : query},
], tokenize = False, add_generation_prompt = True)


output = model.fast_generate(text,
                             sampling_params = SamplingParams(
                                 temperature = 0.8,
                                 top_p = 0.95,
                                 max_tokens = 1024),
                             lora_request = model.load_lora("grpo_saved_lora"),
                             )[0].outputs[0].text

print(output)
